# %% [markdown]
# <a href="https://colab.research.google.com/github/JoanChege/JoanChege/blob/main/Graphs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
icsb = {
    'Arad': ['Zerind', 'Timisoara', 'Sibiu'],
    'Sibiu': ['Fagara', 'RV']
}

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
ICS_Graph =nx.Graph()

# %%
for node in icsb:
  for ne in icsb[node]:
    ICS_Graph.add_edge(node, ne, color='black')

# %%
x=nx.spring_layout(ICS_Graph)
colors=[ICS_Graph[u][v]['color']for u, v in ICS_Graph.edges()]
nx.draw(ICS_Graph, x, node_color='#30D5C8', edge_color=colors, width=2, with_labels=True)
plt.show()
